# %%
import numpy as np
import pandas as pd

# %%
#load the dataset
data=pd.read_csv('/content/Advertising.csv')

# %%
#print first 5 rows
data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#print last 5 rows
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
#printing information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
#printing the shape of the dataset
data.shape
# Out:
# (200, 5)

# %%
#returns numerical description
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
#dropping the unnamed column 0
data=data.drop(columns=["Unnamed: 0"])

# %%
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
x=data[['TV','Radio','Newspaper']]

# %%
y=data[['Sales']]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      Sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train)
# Out:
# 160

# %%
len(x_test)
# Out:
# 40

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 79   116.0    7.7       23.1
# 197  177.0    9.3        6.4
# 38    43.1   26.7       35.1
# 24    62.3   12.6       18.3
# 122  224.0    2.4       15.6
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# 18    69.2   20.5       18.3
# 55   198.9   49.4       60.0
# 75    16.9   43.7       89.4
# 150  280.7   13.9       37.0
# 104  238.2   34.3        5.3
# 135   48.3   47.0        8.5
# 137  273.7   28.9       59.7
# 164  117.2   14.7        5.4
# 76    27.5    1.6       20.7

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %%
x_test_scaled
# Out:
# array([[ 0.31350707,  0.4449903 ,  0.72998755],
#        [ 0.66800269,  1.51564365,  0.72998755],
#        [ 1.74256755,  0.2442428 ,  0.39176938],
#        [-1.37034714,  0.77956947,  0.46692898],
#        [ 0.94495239,  1.64947532, -1.11142249],
#        [-0.6613559 ,  0.71265364,  0.72998755],
#        [ 0.90064044,  1.24798031, -0.20950737],
#        [-0.9383056 , -0.89332639, -0.54772554],
#        [ 0.96710837, -1.42865306, -0.73562452],
#        [ 0.44644292, -0.15725221, -0.05918818],
#        [-1.14878738, -0.02342054, -1.14900229],
#        [-0.87183767, -1.2948214 , -0.13434777],
#        [ 1.10004423, -1.42865306,  1.93254105],
#        [-1.43681507,  0.31115863, -0.88594371],
#        [ 0.04763535, -1.4955689 , -0.24708716],
#        [ 0.39105298, -1.16098973,  0.09113101],
#        [-1.41465909,  0.2442428 ,  0.31660979],
#        [ 0.69015867, -0.09033638, -0.69804473],
#        [-0.6613559 , -0.29108388, -0.02160838],
#        [ 1.13327819,  0.17732696, -0.81078412],
#        [ 1.04465429,  0.51190613,  1.55674308],
#        [-0.7499798 ,  0.77956947,  3.05993496],
#        [-1.07124146,  1.04723281, -0.81078412],
#        [ 1.27729204,  0.77956947,  1.48158349],
#        [-0.72782383, -1.02715806, -1.22416188],
#        [-0.90507164, -1.4955689 , -0.43498615],
#        [ 0.86740648,  1.24798031,  0.01597141],
#        [ 0.04763535, -0.69257889, -0.84836391],
#        [-0.52842004, -0.89332639, -0.28466696],
#        [-1.40358111,  0.17732696, -1.14900229],
#        [ 0.71231464, -1.4955689 , -0.43498615],
#        [-0.72782383, -0.29108388, -0.54772554],
#        [ 0.70123665,  1.64947532,  1.03062593],
#        [-1.3149572 ,  1.24798031,  2.12044004],
#        [ 1.60963169, -0.75949472,  0.1662906 ],
#        [ 1.14435618,  0.6457378 , -1.0362629 ],
#        [-0.96046158,  1.51564365, -0.92352351],
#        [ 1.53208577,  0.2442428 ,  0.99304613],
#        [-0.19608039, -0.69257889, -1.0362629 ],
#        [-1.19309933, -1.56248473, -0.47256595]])

# %%
x_train_scaled
# Out:
# array([[-0.39857414, -1.04592634, -0.319901  ],
#        [ 0.32637621, -0.91009175, -1.15898561],
#        [-1.26613768,  0.24450226,  0.27239401],
#        [-1.04033347, -0.70633986, -0.56669059],
#        [ 0.88494452, -1.38551281, -0.71476435],
#        [-1.32555984, -1.31759551, -0.81348018],
#        [-0.94525801, -0.43467068,  0.5191836 ],
#        [-0.03015675,  0.04075038, -0.51733268],
#        [-0.54118732, -1.18176092,  0.22303609],
#        [-0.87395142,  0.31241955, -0.66540643],
#        [-0.85018255,  1.60284815,  0.22303609],
#        [ 0.21941633, -1.04592634, -0.8628381 ],
#        [-1.6820928 ,  1.73868274,  2.24671072],
#        [-1.69397723,  1.05950979,  1.01276278],
#        [-0.87395142, -1.5213474 , -0.76412226],
#        [-0.24407652, -1.18176092,  0.07496234],
#        [-0.90960471, -0.36675339, -0.8628381 ],
#        [ 1.6574326 ,  1.33117897,  1.06212069],
#        [-1.55136404, -0.16300151, -0.61604851],
#        [ 0.56406485, -1.31759551, -1.20834352],
#        [ 1.59801044, -0.84217445, -1.15898561],
#        [ 0.40956724, -0.09508421, -0.36925892],
#        [-0.44611187, -0.36675339,  0.42046776],
#        [-1.50382632,  0.85575791,  1.75313154],
#        [ 1.66931703, -1.24967822, -1.06026977],
#        [-1.55136404, -0.43467068, -0.36925892],
#        [ 1.70497033,  0.31241955, -1.4057752 ],
#        [-1.56324848, -0.70633986, -0.319901  ],
#        [-0.18465436, -1.24967822, -1.01091185],
#        [-1.48005745,  1.12742709, -1.01091185],
#        [-0.58872505, -0.91009175, -1.30705936],
#        [-0.82641369, -1.5213474 , -1.01091185],
#        [ 0.45710497, -0.2988361 , -0.22118517],
#        [ 0.32637621,  0.71992332,  0.42046776],
#        [-0.29161425,  0.92367521,  2.44414239],
#        [ 0.70667804, -0.16300151, -0.96155394],
#        [-0.08957891,  0.44825414, -0.8628381 ],
#        [ 0.40956724,  1.39909627, -1.4057752 ],
#        [ 0.86117565, -1.24967822,  0.96340486],
#        [ 1.08697986,  1.05950979, -0.319901  ],
#        [-1.57513291,  1.53493086,  1.95056321],
#        [-0.35103641,  0.38033685, -0.76412226],
#        [-0.7194538 , -0.91009175,  0.27239401],
#        [ 0.49275826,  0.38033685, -0.56669059],
#        [-0.88583585, -0.84217445, -1.15898561],
#        [ 0.51652713, -0.2988361 ,  1.75313154],
#        [-0.76699153,  0.85575791,  0.96340486],
#        [ 1.38409066,  1.39909627, -1.20834352],
#        [-1.3136754 ,  1.26326168, -1.20834352],
#        [ 1.3246685 ,  1.33117897,  1.21019445],
#        [-1.62267064, -0.50258798,  0.96340486],
#        [ 0.51652713,  0.85575791,  2.24671072],
#        [ 1.74062362,  0.92367521,  3.48065866],
#        [ 1.37220623, -0.16300151, -1.45513311],
#        [ 0.7661002 ,  0.10866767, -1.25770144],
#        [-0.00638788,  0.85575791, -1.15898561],
#        [-0.22030766, -0.2988361 ,  0.22303609],
#        [-1.09975563,  0.65200603, -0.319901  ],
#        [ 1.07509543, -0.43467068, -0.36925892],
#        [-0.10146334,  0.24450226,  0.8153311 ],
#        [ 0.36202951, -0.84217445,  1.40762612],
#        [-0.62437835, -1.4534301 ,  0.02560442],
#        [ 0.83740679,  0.71992332,  0.37110984],
#        [-0.11334777, -1.4534301 , -1.01091185],
#        [ 1.25336191,  0.24450226, -1.20834352],
#        [-0.63626278, -0.57050527,  0.42046776],
#        [-0.99279574, -1.18176092, -0.27054309],
#        [ 1.063211  , -0.50258798, -0.12246933],
#        [ 0.30260735, -0.50258798, -1.35641728],
#        [ 1.07509543, -1.04592634, -1.06026977],
#        [-1.57513291,  0.9915925 , -0.41861684],
#        [ 0.95625111,  0.9915925 ,  1.95056321],
#        [ 1.58612601,  1.33117897,  1.80248946],
#        [ 0.25506962,  1.12742709,  0.37110984],
#        [ 0.58783372,  0.51617144,  0.42046776],
#        [-0.31538311,  0.78784062, -0.8628381 ],
#        [-0.22030766,  1.33117897, -0.07311142],
#        [-1.48005745,  0.17658497,  0.66725735],
#        [ 0.15999417,  0.92367521, -1.10962769],
#        [ 1.17017089,  0.31241955, -0.36925892],
#        [ 0.62348701, -0.02716692,  0.07496234],
#        [-1.62267064, -1.5213474 , -0.22118517],
#        [-1.72963052, -0.77425716, -1.20834352],
#        [-0.67191607,  1.39909627,  1.01276278],
#        [ 1.33655293, -1.31759551, -0.51733268],
#        [ 0.93248225, -0.43467068, -0.17182725],
#        [ 1.22959305, -0.09508421,  0.02560442],
#        [ 1.11074873,  1.80660003,  0.71661527],
#        [ 1.063211  , -1.24967822,  0.32175193],
#        [ 0.93248225,  0.9915925 ,  0.12432026],
#        [ 0.77798463,  0.04075038,  1.3582682 ],
#        [ 1.063211  ,  1.26326168, -0.56669059],
#        [-0.50553403, -0.57050527, -0.96155394],
#        [ 0.44522053, -0.09508421, -1.01091185],
#        [ 0.67102474, -0.97800904, -0.17182725],
#        [-1.26613768,  0.17658497, -0.46797476],
#        [ 0.01738098,  1.26326168,  1.40762612],
#        [-0.14900107,  1.60284815,  1.45698404],
#        [ 0.38579837,  1.60284815,  1.40762612],
#        [ 0.82552236,  0.71992332,  0.76597319],
#        [ 0.07680314, -1.38551281, -1.06026977],
#        [ 1.50293498, -1.38551281, -0.319901  ],
#        [ 0.65914031,  1.53493086, -0.51733268],
#        [-0.99279574, -0.77425716,  0.32175193],
#        [-0.87395142,  0.24450226, -0.36925892],
#        [-0.64814721, -1.4534301 , -1.10962769],
#        [-0.35103641, -0.2309188 , -0.91219602],
#        [ 0.89682895, -0.97800904,  1.30891028],
#        [-1.44440416, -1.4534301 ,  0.17367817],
#        [-0.96902687,  1.46701356,  0.27239401],
#        [ 1.17017089,  0.51617144, -0.46797476],
#        [ 0.81363793, -1.18176092, -0.12246933],
#        [-0.48176516,  1.67076544,  1.06212069],
#        [-1.6820928 , -1.38551281, -1.4057752 ],
#        [-0.62437835, -1.04592634, -1.10962769],
#        [ 0.71856247,  0.44825414, -1.01091185],
#        [ 0.1718786 , -0.16300151,  0.86468902],
#        [ 1.37220623, -1.38551281,  0.66725735],
#        [ 1.56235714,  1.12742709,  1.25955236],
#        [-1.46817302,  0.71992332, -0.51733268],
#        [ 1.50293498,  1.73868274,  0.56854152],
#        [-1.3493287 ,  1.05950979,  1.75313154],
#        [ 0.67102474, -1.18176092, -0.51733268],
#        [ 1.63366374,  1.39909627,  2.04927905],
#        [-0.56495619,  0.44825414, -1.06026977],
#        [ 1.33655293,  0.38033685, -0.71476435],
#        [-0.70756937, -1.5213474 , -0.319901  ],
#        [ 0.58783372, -1.31759551,  0.22303609],
#        [-0.66003164, -1.24967822, -1.06026977],
#        [ 0.71856247,  1.80660003,  0.37110984],
#        [ 0.92059781, -0.50258798,  0.96340486],
#        [-0.73133823,  0.17658497,  2.14799488],
#        [ 1.03944213, -1.18176092, -0.319901  ],
#        [-0.1608855 , -0.2309188 , -0.66540643],
#        [ 0.26695405, -0.2988361 ,  0.02560442],
#        [-1.57513291, -1.24967822,  0.07496234],
#        [-1.07598676, -0.70633986,  0.66725735],
#        [-0.89772028,  1.80660003,  0.76597319],
#        [-0.00638788, -1.4534301 , -0.27054309],
#        [ 0.19564746,  1.33117897, -1.30705936],
#        [-1.25425324,  1.12742709,  0.76597319],
#        [ 0.78986906,  1.26326168,  0.46982568],
#        [-1.25425324,  0.17658497, -0.46797476],
#        [-1.77716825,  1.12742709, -1.06026977],
#        [-0.33915198, -0.97800904,  0.91404694],
#        [ 0.44522053, -0.36675339, -0.61604851],
#        [-0.17276993,  1.26326168,  0.76597319],
#        [-0.1252322 , -0.57050527, -0.22118517],
#        [-0.46988073,  1.19534438,  1.65441571],
#        [ 0.75421577,  0.10866767, -0.81348018],
#        [-1.56324848, -0.09508421,  1.01276278],
#        [ 0.98001997, -0.97800904, -1.06026977],
#        [ 0.81363793,  0.31241955,  1.16083653],
#        [ 1.6217793 , -0.63842257, -1.30705936],
#        [-0.48176516, -0.57050527,  0.07496234],
#        [-1.48005745, -0.77425716, -0.0237535 ],
#        [ 0.64725588,  0.65200603,  0.8153311 ],
#        [ 0.80175349,  0.71992332,  1.45698404],
#        [ 0.18376303, -0.84217445, -0.61604851],
#        [ 1.55047271, -0.84217445, -0.41861684]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lv=LinearRegression()

# %%
lv.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lv.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([[16.13398822],
#        [20.51245401],
#        [20.92530113],
#        [10.7212509 ],
#        [21.80902927],
#        [13.22101425],
#        [20.56346722],
#        [ 7.52507203],
#        [13.17103771],
#        [14.86887606],
#        [ 9.16241964],
#        [ 6.66316907],
#        [13.85657691],
#        [ 9.04604285],
#        [ 9.54977743],
#        [11.81810717],
#        [ 9.02256735],
#        [15.93324714],
#        [10.31657728],
#        [18.35592747],
#        [19.1365663 ],
#        [13.23840264],
#        [12.52064088],
#        [20.76867756],
#        [ 7.89111811],
#        [ 5.94664502],
#        [20.45382921],
#        [11.79013133],
#        [ 9.08786322],
#        [ 8.77275571],
#        [12.04152211],
#        [10.02970477],
#        [21.03881542],
#        [12.37551213],
#        [17.55631346],
#        [19.71321253],
#        [14.26143714],
#        [20.17373003],
#        [10.85872587],
#        [ 4.66849344]])

# %%
y_test
# Out:
#      Sales
# 95      16
# 15      22
# 30      21
# 158      7
# 128     24
# 115     12
# 69      22
# 170      8
# 174     11
# 45      14
# 66       9
# 182      8
# 165     11
# 78       5
# 186     10
# 177     11
# 56       5
# 152     16
# 82      11
# 68      18
# 124     19
# 16      12
# 148     10
# 93      22
# 65       9
# 60       8
# 84      21
# 67      13
# 125     10
# 132      5
# 9       10
# 18      11
# 55      23
# 75       8
# 150     16
# 104     20
# 135     11
# 137     20
# 164     11
# 76       6

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8811836354878553

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred,c='g')
